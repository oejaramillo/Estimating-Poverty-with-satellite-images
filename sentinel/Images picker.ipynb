# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import rasterio
from rasterio.transform import from_bounds
from sentinelhub import (
    SHConfig,
    SentinelHubRequest,
    DataCollection,
    MimeType,
    CRS,
    BBox,
    bbox_to_dimensions
)
from dotenv import load_dotenv
from shapely.geometry import box
import geopandas as gpd

# %% [markdown]
# We want to extract all the city of Quito in a grid of images that cover the entire city, we this approach we hope
# - **Complete spatial coverage**
# - **Structured data for deep learning**: So the model can learn patterns from individual tiles while mantaining an organized spatial representation.
# - **Comparison  across areas**
# - **Scalability**

# %% [markdown]
# To define the grid size is important to have the best detail as possible, Sentinel-2 has 10m, 20m and 60m resolutions, we aim to use 10m pixels, and a grid of 1 $km^{2}$, we need to ensure constent images, beware of clouds

# %%
# Load SentinelHub API credentials
load_dotenv()
# Out:
# True

# %%
config = SHConfig()
config.sh_client_id = os.getenv("COPERNICUS_CLIENT_ID")
config.sh_client_secret = os.getenv("COPERNICUS_CLIENT_SECRET")
config.sh_base_url = 'https://sh.dataspace.copernicus.eu'
config.sh_token_url = 'https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token'

# %%
# Define Quito's bounding box (approximate)
quito_bbox_wgs84 = [-78.6, -0.4, -78.3, -0.1]  # [min_lon, min_lat, max_lon, max_lat]
resolution = 10  # Sentinel-2 resolution (10m per pixel)
tile_size_km = 1  # Grid tile size (1km²)
tile_size_meters = tile_size_km * 1000  # Convert km to meters

# %%
# Generate grid over Quito
def generate_grid(bbox, tile_size):
    """Generates a grid of bounding boxes within a larger bounding box."""
    minx, miny, maxx, maxy = bbox
    grid_tiles = []
    for x in np.arange(minx, maxx, tile_size / 111320):  # Convert meters to degrees
        for y in np.arange(miny, maxy, tile_size / 111320):
            grid_tiles.append(BBox(bbox=[x, y, x + (tile_size / 111320), y + (tile_size / 111320)], crs=CRS.WGS84))
    return grid_tiles

grid_boxes = generate_grid(quito_bbox_wgs84, tile_size_meters)

print(f"Generated {len(grid_boxes)} tiles over Quito.")
# Out:
# Generated 1156 tiles over Quito.

# %%
# Fetch images for each grid tile
output_dir = "quito_satellite_images"
os.makedirs(output_dir, exist_ok=True)

output_dir_uint16 = "quito_satellite_images/uint16"
output_dir_uint8 = "quito_satellite_images/uint8"
os.makedirs(output_dir_uint16, exist_ok=True)
os.makedirs(output_dir_uint8, exist_ok=True)

# %%
# Define Evalscript for Multi-Band Data (True Color + NIR + SWIR) NIR and SWIR bands useful to detect urban infraestructure, water access, vegetation and green
evalscript_multiband = """
    //VERSION=3

    function setup() {
        return {
            input: [{
                bands: ["B02", "B03", "B04", "B08", "B11", "B12", "SCL"]
            }],
            output: {
                bands: 6,
                sampleType: "UINT16"
            }
        };
    }

    function evaluatePixel(sample) {
        // Sentinel-2 Scene Classification Layer (SCL) values:
        // 3 = Vegetation, 4 = Bare Soil, 5 = Water, 6 = Urban/Artificial
        // 9 = Cirrus Clouds, 10 = High Clouds, 11 = Thin Clouds
        if (sample.SCL == 3 || sample.SCL == 4 || sample.SCL == 5 || sample.SCL == 6) {
            return [
                sample.B02 * 10000,  // Blue
                sample.B03 * 10000,  // Green
                sample.B04 * 10000,  // Red
                sample.B08 * 10000,  // Near-Infrared (NIR)
                sample.B11 * 10000,  // SWIR1
                sample.B12 * 10000   // SWIR2
            ];
        } else {
            return [0, 0, 0, 0, 0, 0];  // Mask clouds as black
        }
    }

"""

# %%
# Define Evalscript for true color just RGB bands for human visualization
evalscript_true_color = """
    //VERSION=3

    function setup() {
        return {
            input: [{
                bands: ["B02", "B03", "B04", "SCL"]
            }],
            output: {
                bands: 3,
                sampleType: "UINT8"
            }
        };
    }

    function evaluatePixel(sample) {
        // Remove clouds using SCL (scene classification)
        if (sample.SCL == 3 || sample.SCL == 4 || sample.SCL == 5 || sample.SCL == 6) {
            return [
                sample.B04 * 255,  // Red
                sample.B03 * 255,  // Green
                sample.B02 * 255   // Blue
            ];
        } else {
            return [0, 0, 0];  // Mask clouds as black
        }
    }
"""

# %%
for idx, tile_bbox in enumerate(grid_boxes):
    print(f"Processing tile {idx+1}/{len(grid_boxes)}...")

    tile_size = bbox_to_dimensions(tile_bbox, resolution=resolution)

    # Request for Multi-Band TIFF (UINT16)
    request_tiff = SentinelHubRequest(
        evalscript=evalscript_multiband,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=DataCollection.SENTINEL2_L2A.define_from(
                    name="s2l2a", service_url="https://sh.dataspace.copernicus.eu"
                ),
                time_interval=("2022-05-01", "2022-05-20"),
                other_args={"dataFilter": {"mosaickingOrder": "leastCC"}},
            )
        ],
        responses=[SentinelHubRequest.output_response("default", MimeType.TIFF)],
        bbox=tile_bbox,
        size=tile_size,
        config=config,
    )

    tile_img_tiff = request_tiff.get_data()[0]

    # Save Multi-Band Image (UINT16 TIFF)
    tile_tiff_path = os.path.join(output_dir_uint16, f"tile_{idx}.tiff")

    # Adding georefence
    minx, miny, maxx, maxy = tile_bbox  # Get coordinates from SentinelHub BBox
    transform = from_bounds(minx, miny, maxx, maxy, tile_img_tiff.shape[1], tile_img_tiff.shape[0])

    with rasterio.open(
        tile_tiff_path,
        'w',
        driver='GTiff',
        height=tile_img_tiff.shape[0],
        width=tile_img_tiff.shape[1],
        count=tile_img_tiff.shape[2],  # Number of bands
        dtype=rasterio.uint16,
        crs='EPSG:4326', # Assign correct projection (WGS84)
        transform=transform,  # Add geotransform if available
    ) as dst:
        for band in range(tile_img_tiff.shape[2]):
            dst.write(tile_img_tiff[:, :, band], band + 1)

    print(f"{idx} Saved Multi-Band GeoTIFF: {tile_tiff_path}")

    # Request for True Color PNG (UINT8)
    request_png = SentinelHubRequest(
        evalscript=evalscript_true_color,
        input_data=[
            SentinelHubRequest.input_data(
                data_collection=DataCollection.SENTINEL2_L2A.define_from(
                    name="s2l2a", service_url="https://sh.dataspace.copernicus.eu"
                ),
                time_interval=("2022-05-01", "2022-05-20"),
                other_args={"dataFilter": {"mosaickingOrder": "leastCC"}},
            )
        ],
        responses=[SentinelHubRequest.output_response("default", MimeType.PNG)],
        bbox=tile_bbox,
        size=tile_size,
        config=config,
    )

    tile_img_png = request_png.get_data()[0]

    # Save RGB Image as PNG for Visualization
    tile_png_path = os.path.join(output_dir_uint8, f"tile_{idx}.png")
    plt.imsave(tile_png_path, tile_img_png)

    print(f"{idx} Saved True Color PNG: {tile_png_path}")

print("All tiles processed and saved successfully!")
# Out:
# Processing tile 1/1156...
# 0 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_0.tiff
# 0 Saved True Color PNG: quito_satellite_images/uint8/tile_0.png
# Processing tile 2/1156...
# 1 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1.tiff
# 1 Saved True Color PNG: quito_satellite_images/uint8/tile_1.png
# Processing tile 3/1156...
# 2 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_2.tiff
# 2 Saved True Color PNG: quito_satellite_images/uint8/tile_2.png
# Processing tile 4/1156...
# 3 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_3.tiff
# 3 Saved True Color PNG: quito_satellite_images/uint8/tile_3.png
# Processing tile 5/1156...
# 4 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_4.tiff
# 4 Saved True Color PNG: quito_satellite_images/uint8/tile_4.png
# Processing tile 6/1156...
# 5 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_5.tiff
# 5 Saved True Color PNG: quito_satellite_images/uint8/tile_5.png
# Processing tile 7/1156...
# 6 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_6.tiff
# 6 Saved True Color PNG: quito_satellite_images/uint8/tile_6.png
# Processing tile 8/1156...
# 7 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_7.tiff
# 7 Saved True Color PNG: quito_satellite_images/uint8/tile_7.png
# Processing tile 9/1156...
# 8 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_8.tiff
# 8 Saved True Color PNG: quito_satellite_images/uint8/tile_8.png
# Processing tile 10/1156...
# 9 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_9.tiff
# 9 Saved True Color PNG: quito_satellite_images/uint8/tile_9.png
# Processing tile 11/1156...
# 10 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_10.tiff
# 10 Saved True Color PNG: quito_satellite_images/uint8/tile_10.png
# Processing tile 12/1156...
# 11 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_11.tiff
# 11 Saved True Color PNG: quito_satellite_images/uint8/tile_11.png
# Processing tile 13/1156...
# 12 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_12.tiff
# 12 Saved True Color PNG: quito_satellite_images/uint8/tile_12.png
# Processing tile 14/1156...
# 13 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_13.tiff
# 13 Saved True Color PNG: quito_satellite_images/uint8/tile_13.png
# Processing tile 15/1156...
# 14 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_14.tiff
# 14 Saved True Color PNG: quito_satellite_images/uint8/tile_14.png
# Processing tile 16/1156...
# 15 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_15.tiff
# 15 Saved True Color PNG: quito_satellite_images/uint8/tile_15.png
# Processing tile 17/1156...
# 16 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_16.tiff
# 16 Saved True Color PNG: quito_satellite_images/uint8/tile_16.png
# Processing tile 18/1156...
# 17 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_17.tiff
# 17 Saved True Color PNG: quito_satellite_images/uint8/tile_17.png
# Processing tile 19/1156...
# 18 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_18.tiff
# 18 Saved True Color PNG: quito_satellite_images/uint8/tile_18.png
# Processing tile 20/1156...
# 19 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_19.tiff
# 19 Saved True Color PNG: quito_satellite_images/uint8/tile_19.png
# Processing tile 21/1156...
# 20 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_20.tiff
# 20 Saved True Color PNG: quito_satellite_images/uint8/tile_20.png
# Processing tile 22/1156...
# 21 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_21.tiff
# 21 Saved True Color PNG: quito_satellite_images/uint8/tile_21.png
# Processing tile 23/1156...
# 22 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_22.tiff
# 22 Saved True Color PNG: quito_satellite_images/uint8/tile_22.png
# Processing tile 24/1156...
# 23 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_23.tiff
# 23 Saved True Color PNG: quito_satellite_images/uint8/tile_23.png
# Processing tile 25/1156...
# 24 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_24.tiff
# 24 Saved True Color PNG: quito_satellite_images/uint8/tile_24.png
# Processing tile 26/1156...
# 25 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_25.tiff
# 25 Saved True Color PNG: quito_satellite_images/uint8/tile_25.png
# Processing tile 27/1156...
# 26 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_26.tiff
# 26 Saved True Color PNG: quito_satellite_images/uint8/tile_26.png
# Processing tile 28/1156...
# 27 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_27.tiff
# 27 Saved True Color PNG: quito_satellite_images/uint8/tile_27.png
# Processing tile 29/1156...
# 28 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_28.tiff
# 28 Saved True Color PNG: quito_satellite_images/uint8/tile_28.png
# Processing tile 30/1156...
# 29 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_29.tiff
# 29 Saved True Color PNG: quito_satellite_images/uint8/tile_29.png
# Processing tile 31/1156...
# 30 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_30.tiff
# 30 Saved True Color PNG: quito_satellite_images/uint8/tile_30.png
# Processing tile 32/1156...
# 31 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_31.tiff
# 31 Saved True Color PNG: quito_satellite_images/uint8/tile_31.png
# Processing tile 33/1156...
# 32 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_32.tiff
# 32 Saved True Color PNG: quito_satellite_images/uint8/tile_32.png
# Processing tile 34/1156...
# 33 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_33.tiff
# 33 Saved True Color PNG: quito_satellite_images/uint8/tile_33.png
# Processing tile 35/1156...
# 34 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_34.tiff
# 34 Saved True Color PNG: quito_satellite_images/uint8/tile_34.png
# Processing tile 36/1156...
# 35 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_35.tiff
# 35 Saved True Color PNG: quito_satellite_images/uint8/tile_35.png
# Processing tile 37/1156...
# 36 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_36.tiff
# 36 Saved True Color PNG: quito_satellite_images/uint8/tile_36.png
# Processing tile 38/1156...
# 37 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_37.tiff
# 37 Saved True Color PNG: quito_satellite_images/uint8/tile_37.png
# Processing tile 39/1156...
# 38 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_38.tiff
# 38 Saved True Color PNG: quito_satellite_images/uint8/tile_38.png
# Processing tile 40/1156...
# 39 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_39.tiff
# 39 Saved True Color PNG: quito_satellite_images/uint8/tile_39.png
# Processing tile 41/1156...
# 40 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_40.tiff
# 40 Saved True Color PNG: quito_satellite_images/uint8/tile_40.png
# Processing tile 42/1156...
# 41 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_41.tiff
# 41 Saved True Color PNG: quito_satellite_images/uint8/tile_41.png
# Processing tile 43/1156...
# 42 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_42.tiff
# 42 Saved True Color PNG: quito_satellite_images/uint8/tile_42.png
# Processing tile 44/1156...
# 43 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_43.tiff
# 43 Saved True Color PNG: quito_satellite_images/uint8/tile_43.png
# Processing tile 45/1156...
# 44 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_44.tiff
# 44 Saved True Color PNG: quito_satellite_images/uint8/tile_44.png
# Processing tile 46/1156...
# 45 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_45.tiff
# 45 Saved True Color PNG: quito_satellite_images/uint8/tile_45.png
# Processing tile 47/1156...
# 46 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_46.tiff
# 46 Saved True Color PNG: quito_satellite_images/uint8/tile_46.png
# Processing tile 48/1156...
# 47 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_47.tiff
# 47 Saved True Color PNG: quito_satellite_images/uint8/tile_47.png
# Processing tile 49/1156...
# 48 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_48.tiff
# 48 Saved True Color PNG: quito_satellite_images/uint8/tile_48.png
# Processing tile 50/1156...
# 49 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_49.tiff
# 49 Saved True Color PNG: quito_satellite_images/uint8/tile_49.png
# Processing tile 51/1156...
# 50 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_50.tiff
# 50 Saved True Color PNG: quito_satellite_images/uint8/tile_50.png
# Processing tile 52/1156...
# 51 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_51.tiff
# 51 Saved True Color PNG: quito_satellite_images/uint8/tile_51.png
# Processing tile 53/1156...
# 52 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_52.tiff
# 52 Saved True Color PNG: quito_satellite_images/uint8/tile_52.png
# Processing tile 54/1156...
# 53 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_53.tiff
# 53 Saved True Color PNG: quito_satellite_images/uint8/tile_53.png
# Processing tile 55/1156...
# 54 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_54.tiff
# 54 Saved True Color PNG: quito_satellite_images/uint8/tile_54.png
# Processing tile 56/1156...
# 55 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_55.tiff
# 55 Saved True Color PNG: quito_satellite_images/uint8/tile_55.png
# Processing tile 57/1156...
# 56 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_56.tiff
# 56 Saved True Color PNG: quito_satellite_images/uint8/tile_56.png
# Processing tile 58/1156...
# 57 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_57.tiff
# 57 Saved True Color PNG: quito_satellite_images/uint8/tile_57.png
# Processing tile 59/1156...
# 58 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_58.tiff
# 58 Saved True Color PNG: quito_satellite_images/uint8/tile_58.png
# Processing tile 60/1156...
# 59 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_59.tiff
# 59 Saved True Color PNG: quito_satellite_images/uint8/tile_59.png
# Processing tile 61/1156...
# 60 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_60.tiff
# 60 Saved True Color PNG: quito_satellite_images/uint8/tile_60.png
# Processing tile 62/1156...
# 61 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_61.tiff
# 61 Saved True Color PNG: quito_satellite_images/uint8/tile_61.png
# Processing tile 63/1156...
# 62 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_62.tiff
# 62 Saved True Color PNG: quito_satellite_images/uint8/tile_62.png
# Processing tile 64/1156...
# 63 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_63.tiff
# 63 Saved True Color PNG: quito_satellite_images/uint8/tile_63.png
# Processing tile 65/1156...
# 64 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_64.tiff
# 64 Saved True Color PNG: quito_satellite_images/uint8/tile_64.png
# Processing tile 66/1156...
# 65 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_65.tiff
# 65 Saved True Color PNG: quito_satellite_images/uint8/tile_65.png
# Processing tile 67/1156...
# 66 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_66.tiff
# 66 Saved True Color PNG: quito_satellite_images/uint8/tile_66.png
# Processing tile 68/1156...
# 67 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_67.tiff
# 67 Saved True Color PNG: quito_satellite_images/uint8/tile_67.png
# Processing tile 69/1156...
# 68 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_68.tiff
# 68 Saved True Color PNG: quito_satellite_images/uint8/tile_68.png
# Processing tile 70/1156...
# 69 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_69.tiff
# 69 Saved True Color PNG: quito_satellite_images/uint8/tile_69.png
# Processing tile 71/1156...
# 70 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_70.tiff
# 70 Saved True Color PNG: quito_satellite_images/uint8/tile_70.png
# Processing tile 72/1156...
# 71 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_71.tiff
# 71 Saved True Color PNG: quito_satellite_images/uint8/tile_71.png
# Processing tile 73/1156...
# 72 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_72.tiff
# 72 Saved True Color PNG: quito_satellite_images/uint8/tile_72.png
# Processing tile 74/1156...
# 73 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_73.tiff
# 73 Saved True Color PNG: quito_satellite_images/uint8/tile_73.png
# Processing tile 75/1156...
# 74 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_74.tiff
# 74 Saved True Color PNG: quito_satellite_images/uint8/tile_74.png
# Processing tile 76/1156...
# 75 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_75.tiff
# 75 Saved True Color PNG: quito_satellite_images/uint8/tile_75.png
# Processing tile 77/1156...
# 76 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_76.tiff
# 76 Saved True Color PNG: quito_satellite_images/uint8/tile_76.png
# Processing tile 78/1156...
# 77 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_77.tiff
# 77 Saved True Color PNG: quito_satellite_images/uint8/tile_77.png
# Processing tile 79/1156...
# 78 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_78.tiff
# 78 Saved True Color PNG: quito_satellite_images/uint8/tile_78.png
# Processing tile 80/1156...
# 79 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_79.tiff
# 79 Saved True Color PNG: quito_satellite_images/uint8/tile_79.png
# Processing tile 81/1156...
# 80 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_80.tiff
# 80 Saved True Color PNG: quito_satellite_images/uint8/tile_80.png
# Processing tile 82/1156...
# 81 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_81.tiff
# 81 Saved True Color PNG: quito_satellite_images/uint8/tile_81.png
# Processing tile 83/1156...
# 82 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_82.tiff
# 82 Saved True Color PNG: quito_satellite_images/uint8/tile_82.png
# Processing tile 84/1156...
# 83 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_83.tiff
# 83 Saved True Color PNG: quito_satellite_images/uint8/tile_83.png
# Processing tile 85/1156...
# 84 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_84.tiff
# 84 Saved True Color PNG: quito_satellite_images/uint8/tile_84.png
# Processing tile 86/1156...
# 85 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_85.tiff
# 85 Saved True Color PNG: quito_satellite_images/uint8/tile_85.png
# Processing tile 87/1156...
# 86 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_86.tiff
# 86 Saved True Color PNG: quito_satellite_images/uint8/tile_86.png
# Processing tile 88/1156...
# 87 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_87.tiff
# 87 Saved True Color PNG: quito_satellite_images/uint8/tile_87.png
# Processing tile 89/1156...
# 88 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_88.tiff
# 88 Saved True Color PNG: quito_satellite_images/uint8/tile_88.png
# Processing tile 90/1156...
# 89 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_89.tiff
# 89 Saved True Color PNG: quito_satellite_images/uint8/tile_89.png
# Processing tile 91/1156...
# 90 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_90.tiff
# 90 Saved True Color PNG: quito_satellite_images/uint8/tile_90.png
# Processing tile 92/1156...
# 91 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_91.tiff
# 91 Saved True Color PNG: quito_satellite_images/uint8/tile_91.png
# Processing tile 93/1156...
# 92 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_92.tiff
# 92 Saved True Color PNG: quito_satellite_images/uint8/tile_92.png
# Processing tile 94/1156...
# 93 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_93.tiff
# 93 Saved True Color PNG: quito_satellite_images/uint8/tile_93.png
# Processing tile 95/1156...
# 94 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_94.tiff
# 94 Saved True Color PNG: quito_satellite_images/uint8/tile_94.png
# Processing tile 96/1156...
# 95 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_95.tiff
# 95 Saved True Color PNG: quito_satellite_images/uint8/tile_95.png
# Processing tile 97/1156...
# 96 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_96.tiff
# 96 Saved True Color PNG: quito_satellite_images/uint8/tile_96.png
# Processing tile 98/1156...
# 97 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_97.tiff
# 97 Saved True Color PNG: quito_satellite_images/uint8/tile_97.png
# Processing tile 99/1156...
# 98 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_98.tiff
# 98 Saved True Color PNG: quito_satellite_images/uint8/tile_98.png
# Processing tile 100/1156...
# 99 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_99.tiff
# 99 Saved True Color PNG: quito_satellite_images/uint8/tile_99.png
# Processing tile 101/1156...
# 100 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_100.tiff
# 100 Saved True Color PNG: quito_satellite_images/uint8/tile_100.png
# Processing tile 102/1156...
# 101 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_101.tiff
# 101 Saved True Color PNG: quito_satellite_images/uint8/tile_101.png
# Processing tile 103/1156...
# 102 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_102.tiff
# 102 Saved True Color PNG: quito_satellite_images/uint8/tile_102.png
# Processing tile 104/1156...
# 103 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_103.tiff
# 103 Saved True Color PNG: quito_satellite_images/uint8/tile_103.png
# Processing tile 105/1156...
# 104 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_104.tiff
# 104 Saved True Color PNG: quito_satellite_images/uint8/tile_104.png
# Processing tile 106/1156...
# 105 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_105.tiff
# 105 Saved True Color PNG: quito_satellite_images/uint8/tile_105.png
# Processing tile 107/1156...
# 106 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_106.tiff
# 106 Saved True Color PNG: quito_satellite_images/uint8/tile_106.png
# Processing tile 108/1156...
# 107 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_107.tiff
# 107 Saved True Color PNG: quito_satellite_images/uint8/tile_107.png
# Processing tile 109/1156...
# 108 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_108.tiff
# 108 Saved True Color PNG: quito_satellite_images/uint8/tile_108.png
# Processing tile 110/1156...
# 109 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_109.tiff
# 109 Saved True Color PNG: quito_satellite_images/uint8/tile_109.png
# Processing tile 111/1156...
# 110 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_110.tiff
# 110 Saved True Color PNG: quito_satellite_images/uint8/tile_110.png
# Processing tile 112/1156...
# 111 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_111.tiff
# 111 Saved True Color PNG: quito_satellite_images/uint8/tile_111.png
# Processing tile 113/1156...
# 112 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_112.tiff
# 112 Saved True Color PNG: quito_satellite_images/uint8/tile_112.png
# Processing tile 114/1156...
# 113 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_113.tiff
# 113 Saved True Color PNG: quito_satellite_images/uint8/tile_113.png
# Processing tile 115/1156...
# 114 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_114.tiff
# 114 Saved True Color PNG: quito_satellite_images/uint8/tile_114.png
# Processing tile 116/1156...
# 115 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_115.tiff
# 115 Saved True Color PNG: quito_satellite_images/uint8/tile_115.png
# Processing tile 117/1156...
# 116 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_116.tiff
# 116 Saved True Color PNG: quito_satellite_images/uint8/tile_116.png
# Processing tile 118/1156...
# 117 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_117.tiff
# 117 Saved True Color PNG: quito_satellite_images/uint8/tile_117.png
# Processing tile 119/1156...
# 118 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_118.tiff
# 118 Saved True Color PNG: quito_satellite_images/uint8/tile_118.png
# Processing tile 120/1156...
# 119 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_119.tiff
# 119 Saved True Color PNG: quito_satellite_images/uint8/tile_119.png
# Processing tile 121/1156...
# 120 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_120.tiff
# 120 Saved True Color PNG: quito_satellite_images/uint8/tile_120.png
# Processing tile 122/1156...
# 121 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_121.tiff
# 121 Saved True Color PNG: quito_satellite_images/uint8/tile_121.png
# Processing tile 123/1156...
# 122 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_122.tiff
# 122 Saved True Color PNG: quito_satellite_images/uint8/tile_122.png
# Processing tile 124/1156...
# 123 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_123.tiff
# 123 Saved True Color PNG: quito_satellite_images/uint8/tile_123.png
# Processing tile 125/1156...
# 124 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_124.tiff
# 124 Saved True Color PNG: quito_satellite_images/uint8/tile_124.png
# Processing tile 126/1156...
# 125 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_125.tiff
# 125 Saved True Color PNG: quito_satellite_images/uint8/tile_125.png
# Processing tile 127/1156...
# 126 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_126.tiff
# 126 Saved True Color PNG: quito_satellite_images/uint8/tile_126.png
# Processing tile 128/1156...
# 127 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_127.tiff
# 127 Saved True Color PNG: quito_satellite_images/uint8/tile_127.png
# Processing tile 129/1156...
# 128 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_128.tiff
# 128 Saved True Color PNG: quito_satellite_images/uint8/tile_128.png
# Processing tile 130/1156...
# 129 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_129.tiff
# 129 Saved True Color PNG: quito_satellite_images/uint8/tile_129.png
# Processing tile 131/1156...
# 130 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_130.tiff
# 130 Saved True Color PNG: quito_satellite_images/uint8/tile_130.png
# Processing tile 132/1156...
# 131 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_131.tiff
# 131 Saved True Color PNG: quito_satellite_images/uint8/tile_131.png
# Processing tile 133/1156...
# 132 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_132.tiff
# 132 Saved True Color PNG: quito_satellite_images/uint8/tile_132.png
# Processing tile 134/1156...
# 133 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_133.tiff
# 133 Saved True Color PNG: quito_satellite_images/uint8/tile_133.png
# Processing tile 135/1156...
# 134 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_134.tiff
# 134 Saved True Color PNG: quito_satellite_images/uint8/tile_134.png
# Processing tile 136/1156...
# 135 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_135.tiff
# 135 Saved True Color PNG: quito_satellite_images/uint8/tile_135.png
# Processing tile 137/1156...
# 136 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_136.tiff
# 136 Saved True Color PNG: quito_satellite_images/uint8/tile_136.png
# Processing tile 138/1156...
# 137 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_137.tiff
# 137 Saved True Color PNG: quito_satellite_images/uint8/tile_137.png
# Processing tile 139/1156...
# 138 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_138.tiff
# 138 Saved True Color PNG: quito_satellite_images/uint8/tile_138.png
# Processing tile 140/1156...
# 139 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_139.tiff
# 139 Saved True Color PNG: quito_satellite_images/uint8/tile_139.png
# Processing tile 141/1156...
# 140 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_140.tiff
# 140 Saved True Color PNG: quito_satellite_images/uint8/tile_140.png
# Processing tile 142/1156...
# 141 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_141.tiff
# 141 Saved True Color PNG: quito_satellite_images/uint8/tile_141.png
# Processing tile 143/1156...
# 142 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_142.tiff
# 142 Saved True Color PNG: quito_satellite_images/uint8/tile_142.png
# Processing tile 144/1156...
# 143 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_143.tiff
# 143 Saved True Color PNG: quito_satellite_images/uint8/tile_143.png
# Processing tile 145/1156...
# 144 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_144.tiff
# 144 Saved True Color PNG: quito_satellite_images/uint8/tile_144.png
# Processing tile 146/1156...
# 145 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_145.tiff
# 145 Saved True Color PNG: quito_satellite_images/uint8/tile_145.png
# Processing tile 147/1156...
# 146 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_146.tiff
# 146 Saved True Color PNG: quito_satellite_images/uint8/tile_146.png
# Processing tile 148/1156...
# 147 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_147.tiff
# 147 Saved True Color PNG: quito_satellite_images/uint8/tile_147.png
# Processing tile 149/1156...
# 148 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_148.tiff
# 148 Saved True Color PNG: quito_satellite_images/uint8/tile_148.png
# Processing tile 150/1156...
# 149 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_149.tiff
# 149 Saved True Color PNG: quito_satellite_images/uint8/tile_149.png
# Processing tile 151/1156...
# 150 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_150.tiff
# 150 Saved True Color PNG: quito_satellite_images/uint8/tile_150.png
# Processing tile 152/1156...
# 151 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_151.tiff
# 151 Saved True Color PNG: quito_satellite_images/uint8/tile_151.png
# Processing tile 153/1156...
# 152 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_152.tiff
# 152 Saved True Color PNG: quito_satellite_images/uint8/tile_152.png
# Processing tile 154/1156...
# 153 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_153.tiff
# 153 Saved True Color PNG: quito_satellite_images/uint8/tile_153.png
# Processing tile 155/1156...
# 154 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_154.tiff
# 154 Saved True Color PNG: quito_satellite_images/uint8/tile_154.png
# Processing tile 156/1156...
# 155 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_155.tiff
# 155 Saved True Color PNG: quito_satellite_images/uint8/tile_155.png
# Processing tile 157/1156...
# 156 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_156.tiff
# 156 Saved True Color PNG: quito_satellite_images/uint8/tile_156.png
# Processing tile 158/1156...
# 157 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_157.tiff
# 157 Saved True Color PNG: quito_satellite_images/uint8/tile_157.png
# Processing tile 159/1156...
# 158 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_158.tiff
# 158 Saved True Color PNG: quito_satellite_images/uint8/tile_158.png
# Processing tile 160/1156...
# 159 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_159.tiff
# 159 Saved True Color PNG: quito_satellite_images/uint8/tile_159.png
# Processing tile 161/1156...
# 160 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_160.tiff
# 160 Saved True Color PNG: quito_satellite_images/uint8/tile_160.png
# Processing tile 162/1156...
# 161 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_161.tiff
# 161 Saved True Color PNG: quito_satellite_images/uint8/tile_161.png
# Processing tile 163/1156...
# 162 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_162.tiff
# 162 Saved True Color PNG: quito_satellite_images/uint8/tile_162.png
# Processing tile 164/1156...
# 163 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_163.tiff
# 163 Saved True Color PNG: quito_satellite_images/uint8/tile_163.png
# Processing tile 165/1156...
# 164 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_164.tiff
# 164 Saved True Color PNG: quito_satellite_images/uint8/tile_164.png
# Processing tile 166/1156...
# 165 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_165.tiff
# 165 Saved True Color PNG: quito_satellite_images/uint8/tile_165.png
# Processing tile 167/1156...
# 166 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_166.tiff
# 166 Saved True Color PNG: quito_satellite_images/uint8/tile_166.png
# Processing tile 168/1156...
# 167 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_167.tiff
# 167 Saved True Color PNG: quito_satellite_images/uint8/tile_167.png
# Processing tile 169/1156...
# 168 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_168.tiff
# 168 Saved True Color PNG: quito_satellite_images/uint8/tile_168.png
# Processing tile 170/1156...
# 169 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_169.tiff
# 169 Saved True Color PNG: quito_satellite_images/uint8/tile_169.png
# Processing tile 171/1156...
# 170 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_170.tiff
# 170 Saved True Color PNG: quito_satellite_images/uint8/tile_170.png
# Processing tile 172/1156...
# 171 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_171.tiff
# 171 Saved True Color PNG: quito_satellite_images/uint8/tile_171.png
# Processing tile 173/1156...
# 172 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_172.tiff
# 172 Saved True Color PNG: quito_satellite_images/uint8/tile_172.png
# Processing tile 174/1156...
# 173 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_173.tiff
# 173 Saved True Color PNG: quito_satellite_images/uint8/tile_173.png
# Processing tile 175/1156...
# 174 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_174.tiff
# 174 Saved True Color PNG: quito_satellite_images/uint8/tile_174.png
# Processing tile 176/1156...
# 175 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_175.tiff
# 175 Saved True Color PNG: quito_satellite_images/uint8/tile_175.png
# Processing tile 177/1156...
# 176 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_176.tiff
# 176 Saved True Color PNG: quito_satellite_images/uint8/tile_176.png
# Processing tile 178/1156...
# 177 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_177.tiff
# 177 Saved True Color PNG: quito_satellite_images/uint8/tile_177.png
# Processing tile 179/1156...
# 178 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_178.tiff
# 178 Saved True Color PNG: quito_satellite_images/uint8/tile_178.png
# Processing tile 180/1156...
# 179 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_179.tiff
# 179 Saved True Color PNG: quito_satellite_images/uint8/tile_179.png
# Processing tile 181/1156...
# 180 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_180.tiff
# 180 Saved True Color PNG: quito_satellite_images/uint8/tile_180.png
# Processing tile 182/1156...
# 181 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_181.tiff
# 181 Saved True Color PNG: quito_satellite_images/uint8/tile_181.png
# Processing tile 183/1156...
# 182 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_182.tiff
# 182 Saved True Color PNG: quito_satellite_images/uint8/tile_182.png
# Processing tile 184/1156...
# 183 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_183.tiff
# 183 Saved True Color PNG: quito_satellite_images/uint8/tile_183.png
# Processing tile 185/1156...
# 184 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_184.tiff
# 184 Saved True Color PNG: quito_satellite_images/uint8/tile_184.png
# Processing tile 186/1156...
# 185 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_185.tiff
# 185 Saved True Color PNG: quito_satellite_images/uint8/tile_185.png
# Processing tile 187/1156...
# 186 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_186.tiff
# 186 Saved True Color PNG: quito_satellite_images/uint8/tile_186.png
# Processing tile 188/1156...
# 187 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_187.tiff
# 187 Saved True Color PNG: quito_satellite_images/uint8/tile_187.png
# Processing tile 189/1156...
# 188 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_188.tiff
# 188 Saved True Color PNG: quito_satellite_images/uint8/tile_188.png
# Processing tile 190/1156...
# 189 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_189.tiff
# 189 Saved True Color PNG: quito_satellite_images/uint8/tile_189.png
# Processing tile 191/1156...
# 190 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_190.tiff
# 190 Saved True Color PNG: quito_satellite_images/uint8/tile_190.png
# Processing tile 192/1156...
# 191 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_191.tiff
# 191 Saved True Color PNG: quito_satellite_images/uint8/tile_191.png
# Processing tile 193/1156...
# 192 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_192.tiff
# 192 Saved True Color PNG: quito_satellite_images/uint8/tile_192.png
# Processing tile 194/1156...
# 193 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_193.tiff
# 193 Saved True Color PNG: quito_satellite_images/uint8/tile_193.png
# Processing tile 195/1156...
# 194 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_194.tiff
# 194 Saved True Color PNG: quito_satellite_images/uint8/tile_194.png
# Processing tile 196/1156...
# 195 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_195.tiff
# 195 Saved True Color PNG: quito_satellite_images/uint8/tile_195.png
# Processing tile 197/1156...
# 196 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_196.tiff
# 196 Saved True Color PNG: quito_satellite_images/uint8/tile_196.png
# Processing tile 198/1156...
# 197 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_197.tiff
# 197 Saved True Color PNG: quito_satellite_images/uint8/tile_197.png
# Processing tile 199/1156...
# 198 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_198.tiff
# 198 Saved True Color PNG: quito_satellite_images/uint8/tile_198.png
# Processing tile 200/1156...
# 199 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_199.tiff
# 199 Saved True Color PNG: quito_satellite_images/uint8/tile_199.png
# Processing tile 201/1156...
# 200 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_200.tiff
# 200 Saved True Color PNG: quito_satellite_images/uint8/tile_200.png
# Processing tile 202/1156...
# 201 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_201.tiff
# 201 Saved True Color PNG: quito_satellite_images/uint8/tile_201.png
# Processing tile 203/1156...
# 202 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_202.tiff
# 202 Saved True Color PNG: quito_satellite_images/uint8/tile_202.png
# Processing tile 204/1156...
# 203 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_203.tiff
# 203 Saved True Color PNG: quito_satellite_images/uint8/tile_203.png
# Processing tile 205/1156...
# 204 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_204.tiff
# 204 Saved True Color PNG: quito_satellite_images/uint8/tile_204.png
# Processing tile 206/1156...
# 205 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_205.tiff
# 205 Saved True Color PNG: quito_satellite_images/uint8/tile_205.png
# Processing tile 207/1156...
# 206 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_206.tiff
# 206 Saved True Color PNG: quito_satellite_images/uint8/tile_206.png
# Processing tile 208/1156...
# 207 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_207.tiff
# 207 Saved True Color PNG: quito_satellite_images/uint8/tile_207.png
# Processing tile 209/1156...
# 208 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_208.tiff
# 208 Saved True Color PNG: quito_satellite_images/uint8/tile_208.png
# Processing tile 210/1156...
# 209 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_209.tiff
# 209 Saved True Color PNG: quito_satellite_images/uint8/tile_209.png
# Processing tile 211/1156...
# 210 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_210.tiff
# 210 Saved True Color PNG: quito_satellite_images/uint8/tile_210.png
# Processing tile 212/1156...
# 211 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_211.tiff
# 211 Saved True Color PNG: quito_satellite_images/uint8/tile_211.png
# Processing tile 213/1156...
# 212 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_212.tiff
# 212 Saved True Color PNG: quito_satellite_images/uint8/tile_212.png
# Processing tile 214/1156...
# 213 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_213.tiff
# 213 Saved True Color PNG: quito_satellite_images/uint8/tile_213.png
# Processing tile 215/1156...
# 214 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_214.tiff
# 214 Saved True Color PNG: quito_satellite_images/uint8/tile_214.png
# Processing tile 216/1156...
# 215 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_215.tiff
# 215 Saved True Color PNG: quito_satellite_images/uint8/tile_215.png
# Processing tile 217/1156...
# 216 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_216.tiff
# 216 Saved True Color PNG: quito_satellite_images/uint8/tile_216.png
# Processing tile 218/1156...
# 217 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_217.tiff
# 217 Saved True Color PNG: quito_satellite_images/uint8/tile_217.png
# Processing tile 219/1156...
# 218 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_218.tiff
# 218 Saved True Color PNG: quito_satellite_images/uint8/tile_218.png
# Processing tile 220/1156...
# 219 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_219.tiff
# 219 Saved True Color PNG: quito_satellite_images/uint8/tile_219.png
# Processing tile 221/1156...
# 220 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_220.tiff
# 220 Saved True Color PNG: quito_satellite_images/uint8/tile_220.png
# Processing tile 222/1156...
# 221 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_221.tiff
# 221 Saved True Color PNG: quito_satellite_images/uint8/tile_221.png
# Processing tile 223/1156...
# 222 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_222.tiff
# 222 Saved True Color PNG: quito_satellite_images/uint8/tile_222.png
# Processing tile 224/1156...
# 223 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_223.tiff
# 223 Saved True Color PNG: quito_satellite_images/uint8/tile_223.png
# Processing tile 225/1156...
# 224 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_224.tiff
# 224 Saved True Color PNG: quito_satellite_images/uint8/tile_224.png
# Processing tile 226/1156...
# 225 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_225.tiff
# 225 Saved True Color PNG: quito_satellite_images/uint8/tile_225.png
# Processing tile 227/1156...
# 226 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_226.tiff
# 226 Saved True Color PNG: quito_satellite_images/uint8/tile_226.png
# Processing tile 228/1156...
# 227 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_227.tiff
# 227 Saved True Color PNG: quito_satellite_images/uint8/tile_227.png
# Processing tile 229/1156...
# 228 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_228.tiff
# 228 Saved True Color PNG: quito_satellite_images/uint8/tile_228.png
# Processing tile 230/1156...
# 229 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_229.tiff
# 229 Saved True Color PNG: quito_satellite_images/uint8/tile_229.png
# Processing tile 231/1156...
# 230 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_230.tiff
# 230 Saved True Color PNG: quito_satellite_images/uint8/tile_230.png
# Processing tile 232/1156...
# 231 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_231.tiff
# 231 Saved True Color PNG: quito_satellite_images/uint8/tile_231.png
# Processing tile 233/1156...
# 232 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_232.tiff
# 232 Saved True Color PNG: quito_satellite_images/uint8/tile_232.png
# Processing tile 234/1156...
# 233 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_233.tiff
# 233 Saved True Color PNG: quito_satellite_images/uint8/tile_233.png
# Processing tile 235/1156...
# 234 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_234.tiff
# 234 Saved True Color PNG: quito_satellite_images/uint8/tile_234.png
# Processing tile 236/1156...
# 235 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_235.tiff
# 235 Saved True Color PNG: quito_satellite_images/uint8/tile_235.png
# Processing tile 237/1156...
# 236 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_236.tiff
# 236 Saved True Color PNG: quito_satellite_images/uint8/tile_236.png
# Processing tile 238/1156...
# 237 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_237.tiff
# 237 Saved True Color PNG: quito_satellite_images/uint8/tile_237.png
# Processing tile 239/1156...
# 238 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_238.tiff
# 238 Saved True Color PNG: quito_satellite_images/uint8/tile_238.png
# Processing tile 240/1156...
# 239 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_239.tiff
# 239 Saved True Color PNG: quito_satellite_images/uint8/tile_239.png
# Processing tile 241/1156...
# 240 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_240.tiff
# 240 Saved True Color PNG: quito_satellite_images/uint8/tile_240.png
# Processing tile 242/1156...
# 241 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_241.tiff
# 241 Saved True Color PNG: quito_satellite_images/uint8/tile_241.png
# Processing tile 243/1156...
# 242 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_242.tiff
# 242 Saved True Color PNG: quito_satellite_images/uint8/tile_242.png
# Processing tile 244/1156...
# 243 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_243.tiff
# 243 Saved True Color PNG: quito_satellite_images/uint8/tile_243.png
# Processing tile 245/1156...
# 244 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_244.tiff
# 244 Saved True Color PNG: quito_satellite_images/uint8/tile_244.png
# Processing tile 246/1156...
# 245 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_245.tiff
# 245 Saved True Color PNG: quito_satellite_images/uint8/tile_245.png
# Processing tile 247/1156...
# 246 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_246.tiff
# 246 Saved True Color PNG: quito_satellite_images/uint8/tile_246.png
# Processing tile 248/1156...
# 247 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_247.tiff
# 247 Saved True Color PNG: quito_satellite_images/uint8/tile_247.png
# Processing tile 249/1156...
# 248 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_248.tiff
# 248 Saved True Color PNG: quito_satellite_images/uint8/tile_248.png
# Processing tile 250/1156...
# 249 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_249.tiff
# 249 Saved True Color PNG: quito_satellite_images/uint8/tile_249.png
# Processing tile 251/1156...
# 250 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_250.tiff
# 250 Saved True Color PNG: quito_satellite_images/uint8/tile_250.png
# Processing tile 252/1156...
# 251 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_251.tiff
# 251 Saved True Color PNG: quito_satellite_images/uint8/tile_251.png
# Processing tile 253/1156...
# 252 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_252.tiff
# 252 Saved True Color PNG: quito_satellite_images/uint8/tile_252.png
# Processing tile 254/1156...
# 253 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_253.tiff
# 253 Saved True Color PNG: quito_satellite_images/uint8/tile_253.png
# Processing tile 255/1156...
# 254 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_254.tiff
# 254 Saved True Color PNG: quito_satellite_images/uint8/tile_254.png
# Processing tile 256/1156...
# 255 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_255.tiff
# 255 Saved True Color PNG: quito_satellite_images/uint8/tile_255.png
# Processing tile 257/1156...
# 256 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_256.tiff
# 256 Saved True Color PNG: quito_satellite_images/uint8/tile_256.png
# Processing tile 258/1156...
# 257 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_257.tiff
# 257 Saved True Color PNG: quito_satellite_images/uint8/tile_257.png
# Processing tile 259/1156...
# 258 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_258.tiff
# 258 Saved True Color PNG: quito_satellite_images/uint8/tile_258.png
# Processing tile 260/1156...
# 259 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_259.tiff
# 259 Saved True Color PNG: quito_satellite_images/uint8/tile_259.png
# Processing tile 261/1156...
# 260 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_260.tiff
# 260 Saved True Color PNG: quito_satellite_images/uint8/tile_260.png
# Processing tile 262/1156...
# 261 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_261.tiff
# 261 Saved True Color PNG: quito_satellite_images/uint8/tile_261.png
# Processing tile 263/1156...
# 262 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_262.tiff
# 262 Saved True Color PNG: quito_satellite_images/uint8/tile_262.png
# Processing tile 264/1156...
# 263 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_263.tiff
# 263 Saved True Color PNG: quito_satellite_images/uint8/tile_263.png
# Processing tile 265/1156...
# 264 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_264.tiff
# 264 Saved True Color PNG: quito_satellite_images/uint8/tile_264.png
# Processing tile 266/1156...
# 265 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_265.tiff
# 265 Saved True Color PNG: quito_satellite_images/uint8/tile_265.png
# Processing tile 267/1156...
# 266 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_266.tiff
# 266 Saved True Color PNG: quito_satellite_images/uint8/tile_266.png
# Processing tile 268/1156...
# 267 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_267.tiff
# 267 Saved True Color PNG: quito_satellite_images/uint8/tile_267.png
# Processing tile 269/1156...
# 268 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_268.tiff
# 268 Saved True Color PNG: quito_satellite_images/uint8/tile_268.png
# Processing tile 270/1156...
# 269 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_269.tiff
# 269 Saved True Color PNG: quito_satellite_images/uint8/tile_269.png
# Processing tile 271/1156...
# 270 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_270.tiff
# 270 Saved True Color PNG: quito_satellite_images/uint8/tile_270.png
# Processing tile 272/1156...
# 271 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_271.tiff
# 271 Saved True Color PNG: quito_satellite_images/uint8/tile_271.png
# Processing tile 273/1156...
# 272 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_272.tiff
# 272 Saved True Color PNG: quito_satellite_images/uint8/tile_272.png
# Processing tile 274/1156...
# 273 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_273.tiff
# 273 Saved True Color PNG: quito_satellite_images/uint8/tile_273.png
# Processing tile 275/1156...
# 274 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_274.tiff
# 274 Saved True Color PNG: quito_satellite_images/uint8/tile_274.png
# Processing tile 276/1156...
# 275 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_275.tiff
# 275 Saved True Color PNG: quito_satellite_images/uint8/tile_275.png
# Processing tile 277/1156...
# 276 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_276.tiff
# 276 Saved True Color PNG: quito_satellite_images/uint8/tile_276.png
# Processing tile 278/1156...
# 277 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_277.tiff
# 277 Saved True Color PNG: quito_satellite_images/uint8/tile_277.png
# Processing tile 279/1156...
# 278 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_278.tiff
# 278 Saved True Color PNG: quito_satellite_images/uint8/tile_278.png
# Processing tile 280/1156...
# 279 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_279.tiff
# 279 Saved True Color PNG: quito_satellite_images/uint8/tile_279.png
# Processing tile 281/1156...
# 280 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_280.tiff
# 280 Saved True Color PNG: quito_satellite_images/uint8/tile_280.png
# Processing tile 282/1156...
# 281 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_281.tiff
# 281 Saved True Color PNG: quito_satellite_images/uint8/tile_281.png
# Processing tile 283/1156...
# 282 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_282.tiff
# 282 Saved True Color PNG: quito_satellite_images/uint8/tile_282.png
# Processing tile 284/1156...
# 283 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_283.tiff
# 283 Saved True Color PNG: quito_satellite_images/uint8/tile_283.png
# Processing tile 285/1156...
# 284 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_284.tiff
# 284 Saved True Color PNG: quito_satellite_images/uint8/tile_284.png
# Processing tile 286/1156...
# ...
# Processing tile 1066/1156...
# 1065 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1065.tiff
# 1065 Saved True Color PNG: quito_satellite_images/uint8/tile_1065.png
# Processing tile 1067/1156...
# 1066 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1066.tiff
# 1066 Saved True Color PNG: quito_satellite_images/uint8/tile_1066.png
# Processing tile 1068/1156...
# 1067 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1067.tiff
# 1067 Saved True Color PNG: quito_satellite_images/uint8/tile_1067.png
# Processing tile 1069/1156...
# 1068 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1068.tiff
# 1068 Saved True Color PNG: quito_satellite_images/uint8/tile_1068.png
# Processing tile 1070/1156...
# 1069 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1069.tiff
# 1069 Saved True Color PNG: quito_satellite_images/uint8/tile_1069.png
# Processing tile 1071/1156...
# 1070 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1070.tiff
# 1070 Saved True Color PNG: quito_satellite_images/uint8/tile_1070.png
# Processing tile 1072/1156...
# 1071 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1071.tiff
# 1071 Saved True Color PNG: quito_satellite_images/uint8/tile_1071.png
# Processing tile 1073/1156...
# 1072 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1072.tiff
# 1072 Saved True Color PNG: quito_satellite_images/uint8/tile_1072.png
# Processing tile 1074/1156...
# 1073 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1073.tiff
# 1073 Saved True Color PNG: quito_satellite_images/uint8/tile_1073.png
# Processing tile 1075/1156...
# 1074 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1074.tiff
# 1074 Saved True Color PNG: quito_satellite_images/uint8/tile_1074.png
# Processing tile 1076/1156...
# 1075 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1075.tiff
# 1075 Saved True Color PNG: quito_satellite_images/uint8/tile_1075.png
# Processing tile 1077/1156...
# 1076 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1076.tiff
# 1076 Saved True Color PNG: quito_satellite_images/uint8/tile_1076.png
# Processing tile 1078/1156...
# 1077 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1077.tiff
# 1077 Saved True Color PNG: quito_satellite_images/uint8/tile_1077.png
# Processing tile 1079/1156...
# 1078 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1078.tiff
# 1078 Saved True Color PNG: quito_satellite_images/uint8/tile_1078.png
# Processing tile 1080/1156...
# 1079 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1079.tiff
# 1079 Saved True Color PNG: quito_satellite_images/uint8/tile_1079.png
# Processing tile 1081/1156...
# 1080 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1080.tiff
# 1080 Saved True Color PNG: quito_satellite_images/uint8/tile_1080.png
# Processing tile 1082/1156...
# 1081 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1081.tiff
# 1081 Saved True Color PNG: quito_satellite_images/uint8/tile_1081.png
# Processing tile 1083/1156...
# 1082 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1082.tiff
# 1082 Saved True Color PNG: quito_satellite_images/uint8/tile_1082.png
# Processing tile 1084/1156...
# 1083 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1083.tiff
# 1083 Saved True Color PNG: quito_satellite_images/uint8/tile_1083.png
# Processing tile 1085/1156...
# 1084 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1084.tiff
# 1084 Saved True Color PNG: quito_satellite_images/uint8/tile_1084.png
# Processing tile 1086/1156...
# 1085 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1085.tiff
# 1085 Saved True Color PNG: quito_satellite_images/uint8/tile_1085.png
# Processing tile 1087/1156...
# 1086 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1086.tiff
# 1086 Saved True Color PNG: quito_satellite_images/uint8/tile_1086.png
# Processing tile 1088/1156...
# 1087 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1087.tiff
# 1087 Saved True Color PNG: quito_satellite_images/uint8/tile_1087.png
# Processing tile 1089/1156...
# 1088 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1088.tiff
# 1088 Saved True Color PNG: quito_satellite_images/uint8/tile_1088.png
# Processing tile 1090/1156...
# 1089 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1089.tiff
# 1089 Saved True Color PNG: quito_satellite_images/uint8/tile_1089.png
# Processing tile 1091/1156...
# 1090 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1090.tiff
# 1090 Saved True Color PNG: quito_satellite_images/uint8/tile_1090.png
# Processing tile 1092/1156...
# 1091 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1091.tiff
# 1091 Saved True Color PNG: quito_satellite_images/uint8/tile_1091.png
# Processing tile 1093/1156...
# 1092 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1092.tiff
# 1092 Saved True Color PNG: quito_satellite_images/uint8/tile_1092.png
# Processing tile 1094/1156...
# 1093 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1093.tiff
# 1093 Saved True Color PNG: quito_satellite_images/uint8/tile_1093.png
# Processing tile 1095/1156...
# 1094 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1094.tiff
# 1094 Saved True Color PNG: quito_satellite_images/uint8/tile_1094.png
# Processing tile 1096/1156...
# 1095 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1095.tiff
# 1095 Saved True Color PNG: quito_satellite_images/uint8/tile_1095.png
# Processing tile 1097/1156...
# 1096 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1096.tiff
# 1096 Saved True Color PNG: quito_satellite_images/uint8/tile_1096.png
# Processing tile 1098/1156...
# 1097 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1097.tiff
# 1097 Saved True Color PNG: quito_satellite_images/uint8/tile_1097.png
# Processing tile 1099/1156...
# 1098 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1098.tiff
# 1098 Saved True Color PNG: quito_satellite_images/uint8/tile_1098.png
# Processing tile 1100/1156...
# 1099 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1099.tiff
# 1099 Saved True Color PNG: quito_satellite_images/uint8/tile_1099.png
# Processing tile 1101/1156...
# 1100 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1100.tiff
# 1100 Saved True Color PNG: quito_satellite_images/uint8/tile_1100.png
# Processing tile 1102/1156...
# 1101 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1101.tiff
# 1101 Saved True Color PNG: quito_satellite_images/uint8/tile_1101.png
# Processing tile 1103/1156...
# 1102 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1102.tiff
# 1102 Saved True Color PNG: quito_satellite_images/uint8/tile_1102.png
# Processing tile 1104/1156...
# 1103 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1103.tiff
# 1103 Saved True Color PNG: quito_satellite_images/uint8/tile_1103.png
# Processing tile 1105/1156...
# 1104 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1104.tiff
# 1104 Saved True Color PNG: quito_satellite_images/uint8/tile_1104.png
# Processing tile 1106/1156...
# 1105 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1105.tiff
# 1105 Saved True Color PNG: quito_satellite_images/uint8/tile_1105.png
# Processing tile 1107/1156...
# 1106 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1106.tiff
# 1106 Saved True Color PNG: quito_satellite_images/uint8/tile_1106.png
# Processing tile 1108/1156...
# 1107 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1107.tiff
# 1107 Saved True Color PNG: quito_satellite_images/uint8/tile_1107.png
# Processing tile 1109/1156...
# 1108 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1108.tiff
# 1108 Saved True Color PNG: quito_satellite_images/uint8/tile_1108.png
# Processing tile 1110/1156...
# 1109 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1109.tiff
# 1109 Saved True Color PNG: quito_satellite_images/uint8/tile_1109.png
# Processing tile 1111/1156...
# 1110 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1110.tiff
# 1110 Saved True Color PNG: quito_satellite_images/uint8/tile_1110.png
# Processing tile 1112/1156...
# 1111 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1111.tiff
# 1111 Saved True Color PNG: quito_satellite_images/uint8/tile_1111.png
# Processing tile 1113/1156...
# 1112 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1112.tiff
# 1112 Saved True Color PNG: quito_satellite_images/uint8/tile_1112.png
# Processing tile 1114/1156...
# 1113 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1113.tiff
# 1113 Saved True Color PNG: quito_satellite_images/uint8/tile_1113.png
# Processing tile 1115/1156...
# 1114 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1114.tiff
# 1114 Saved True Color PNG: quito_satellite_images/uint8/tile_1114.png
# Processing tile 1116/1156...
# 1115 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1115.tiff
# 1115 Saved True Color PNG: quito_satellite_images/uint8/tile_1115.png
# Processing tile 1117/1156...
# 1116 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1116.tiff
# 1116 Saved True Color PNG: quito_satellite_images/uint8/tile_1116.png
# Processing tile 1118/1156...
# 1117 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1117.tiff
# 1117 Saved True Color PNG: quito_satellite_images/uint8/tile_1117.png
# Processing tile 1119/1156...
# 1118 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1118.tiff
# 1118 Saved True Color PNG: quito_satellite_images/uint8/tile_1118.png
# Processing tile 1120/1156...
# 1119 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1119.tiff
# 1119 Saved True Color PNG: quito_satellite_images/uint8/tile_1119.png
# Processing tile 1121/1156...
# 1120 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1120.tiff
# 1120 Saved True Color PNG: quito_satellite_images/uint8/tile_1120.png
# Processing tile 1122/1156...
# 1121 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1121.tiff
# 1121 Saved True Color PNG: quito_satellite_images/uint8/tile_1121.png
# Processing tile 1123/1156...
# 1122 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1122.tiff
# 1122 Saved True Color PNG: quito_satellite_images/uint8/tile_1122.png
# Processing tile 1124/1156...
# 1123 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1123.tiff
# 1123 Saved True Color PNG: quito_satellite_images/uint8/tile_1123.png
# Processing tile 1125/1156...
# 1124 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1124.tiff
# 1124 Saved True Color PNG: quito_satellite_images/uint8/tile_1124.png
# Processing tile 1126/1156...
# 1125 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1125.tiff
# 1125 Saved True Color PNG: quito_satellite_images/uint8/tile_1125.png
# Processing tile 1127/1156...
# 1126 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1126.tiff
# 1126 Saved True Color PNG: quito_satellite_images/uint8/tile_1126.png
# Processing tile 1128/1156...
# 1127 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1127.tiff
# 1127 Saved True Color PNG: quito_satellite_images/uint8/tile_1127.png
# Processing tile 1129/1156...
# 1128 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1128.tiff
# 1128 Saved True Color PNG: quito_satellite_images/uint8/tile_1128.png
# Processing tile 1130/1156...
# 1129 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1129.tiff
# 1129 Saved True Color PNG: quito_satellite_images/uint8/tile_1129.png
# Processing tile 1131/1156...
# 1130 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1130.tiff
# 1130 Saved True Color PNG: quito_satellite_images/uint8/tile_1130.png
# Processing tile 1132/1156...
# 1131 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1131.tiff
# 1131 Saved True Color PNG: quito_satellite_images/uint8/tile_1131.png
# Processing tile 1133/1156...
# 1132 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1132.tiff
# 1132 Saved True Color PNG: quito_satellite_images/uint8/tile_1132.png
# Processing tile 1134/1156...
# 1133 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1133.tiff
# 1133 Saved True Color PNG: quito_satellite_images/uint8/tile_1133.png
# Processing tile 1135/1156...
# 1134 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1134.tiff
# 1134 Saved True Color PNG: quito_satellite_images/uint8/tile_1134.png
# Processing tile 1136/1156...
# 1135 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1135.tiff
# 1135 Saved True Color PNG: quito_satellite_images/uint8/tile_1135.png
# Processing tile 1137/1156...
# 1136 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1136.tiff
# 1136 Saved True Color PNG: quito_satellite_images/uint8/tile_1136.png
# Processing tile 1138/1156...
# 1137 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1137.tiff
# 1137 Saved True Color PNG: quito_satellite_images/uint8/tile_1137.png
# Processing tile 1139/1156...
# 1138 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1138.tiff
# 1138 Saved True Color PNG: quito_satellite_images/uint8/tile_1138.png
# Processing tile 1140/1156...
# 1139 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1139.tiff
# 1139 Saved True Color PNG: quito_satellite_images/uint8/tile_1139.png
# Processing tile 1141/1156...
# 1140 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1140.tiff
# 1140 Saved True Color PNG: quito_satellite_images/uint8/tile_1140.png
# Processing tile 1142/1156...
# 1141 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1141.tiff
# 1141 Saved True Color PNG: quito_satellite_images/uint8/tile_1141.png
# Processing tile 1143/1156...
# 1142 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1142.tiff
# 1142 Saved True Color PNG: quito_satellite_images/uint8/tile_1142.png
# Processing tile 1144/1156...
# 1143 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1143.tiff
# 1143 Saved True Color PNG: quito_satellite_images/uint8/tile_1143.png
# Processing tile 1145/1156...
# 1144 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1144.tiff
# 1144 Saved True Color PNG: quito_satellite_images/uint8/tile_1144.png
# Processing tile 1146/1156...
# 1145 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1145.tiff
# 1145 Saved True Color PNG: quito_satellite_images/uint8/tile_1145.png
# Processing tile 1147/1156...
# 1146 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1146.tiff
# 1146 Saved True Color PNG: quito_satellite_images/uint8/tile_1146.png
# Processing tile 1148/1156...
# 1147 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1147.tiff
# 1147 Saved True Color PNG: quito_satellite_images/uint8/tile_1147.png
# Processing tile 1149/1156...
# 1148 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1148.tiff
# 1148 Saved True Color PNG: quito_satellite_images/uint8/tile_1148.png
# Processing tile 1150/1156...
# 1149 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1149.tiff
# 1149 Saved True Color PNG: quito_satellite_images/uint8/tile_1149.png
# Processing tile 1151/1156...
# 1150 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1150.tiff
# 1150 Saved True Color PNG: quito_satellite_images/uint8/tile_1150.png
# Processing tile 1152/1156...
# 1151 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1151.tiff
# 1151 Saved True Color PNG: quito_satellite_images/uint8/tile_1151.png
# Processing tile 1153/1156...
# 1152 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1152.tiff
# 1152 Saved True Color PNG: quito_satellite_images/uint8/tile_1152.png
# Processing tile 1154/1156...
# 1153 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1153.tiff
# 1153 Saved True Color PNG: quito_satellite_images/uint8/tile_1153.png
# Processing tile 1155/1156...
# 1154 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1154.tiff
# 1154 Saved True Color PNG: quito_satellite_images/uint8/tile_1154.png
# Processing tile 1156/1156...
# 1155 Saved Multi-Band GeoTIFF: quito_satellite_images/uint16/tile_1155.tiff
# 1155 Saved True Color PNG: quito_satellite_images/uint8/tile_1155.png
# All tiles processed and saved successfully!
